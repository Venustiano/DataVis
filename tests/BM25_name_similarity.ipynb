# %% [markdown]
# # BM25 Name Similarity

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Reading the data

# %%
names = pd.read_csv('../slides/data/names.csv',header=None)
names
# Out:
#               0
# 0         Dirck
# 1           Jan
# 2         Reyer
# 3      Cornelis
# 4         Symon
# ...         ...
# 2968   Reynnout
# 2969  Kateleyne
# 2970     Anneke
# 2971      Claes
# 2972        Jan
#
# [2973 rows x 1 columns]

# %%
type(names[0])
# Out:
# pandas.core.series.Series

# %%
# !pip install rank_bm25

# %%
from rank_bm25 import BM25Okapi

corpus = [
    "Hello there good man!",
    "It is quite windy in London",
    "How is the weather today?"
]

tokenized_corpus = [doc.split(" ") for doc in corpus]

bm25 = BM25Okapi(tokenized_corpus)

# %%
tokenized_corpus
# Out:
# [['Hello', 'there', 'good', 'man!'],
#  ['It', 'is', 'quite', 'windy', 'in', 'London'],
#  ['How', 'is', 'the', 'weather', 'today?']]

# %% [markdown]
# ### 2.9 Tokenize lists for BM25 algorithm

# %%
l_names =list(names[0].str.strip().unique())
print("Names:",len(l_names))
# Out:
# Names: 693

# %%
# we may improve results if we make lists of male and female names
tokenized_names = [[char for char in name] for name in l_names]

tokenized_names
# Out:
# [['D', 'i', 'r', 'c', 'k'],
#  ['J', 'a', 'n'],
#  ['R', 'e', 'y', 'e', 'r'],
#  ['C', 'o', 'r', 'n', 'e', 'l', 'i', 's'],
#  ['S', 'y', 'm', 'o', 'n'],
#  ['W', 'i', 'l', 'l', 'e', 'n'],
#  ['J', 'a', 'n', 'n', 'i', 't', 'g', 'e', 'n'],
#  ['M', 'a', 'e', 'r', 't', 'i', 'j', 'n'],
#  ['W', 'i', 'l', 'l', 'e', 'm'],
#  ['I', 'J', 'z', 'a', 'e', 'c', 'k'],
#  ['L', 'a', 'm', 'b', 'r', 'e', 'c', 'h', 't'],
#  ['H', 'e', 'y', 'n', 'd', 'e', 'r', 'i', 'c', 'k'],
#  ['A', 'd', 'r', 'i', 'j', 'a', 'e', 'n'],
#  ['V', 'r', 'a', 'n', 'c', 'k'],
#  ['A', 'l', 'l', 'e', 'r', 't'],
#  ['J', 'a', 'c', 'o', 'b'],
#  ['P', 'i', 'e', 't', 'e', 'r'],
#  ['W', 'e', 'r', 'r', 'e', 'n', 'a', 'e', 'r'],
#  ['C', 'l', 'a', 'e', 's'],
#  ['G', 'h', 'i', 'j', 's', 'b', 'e', 'r', 't'],
#  ['L', 'o', 'u', 'w', 'e', 'n'],
#  ['M', 'e', 'e', 's'],
#  ['M', 'a', 'r', 'i', 't', 'g', 'e', 'n'],
#  ['Q', 'u', 'y', 'e', 'r', 'i', 'j', 'n'],
#  ['A', 'n', 'd', 'r', 'i', 'e', 's'],
# ...

# %%
bm25_names = BM25Okapi(tokenized_names)

# %% [markdown]
# Test to find similar  names

# %%
name = 'Mari'
tokenized_name = [char for char in name]
#tokenized_name
top_fnames = bm25_names.get_top_n(tokenized_name, l_names, n=10)
print("Top names:",top_fnames)
# Out:
# Top names: ['Mari', 'Maeri', 'Marij', 'Marie', 'Marrij', 'Matijs', 'Mary', 'Mart', 'Mare', 'Mariken']
